# %%
from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects

import sys 
sys.path.append("..")

import hls4ml
import numpy as np
from sklearn.metrics import accuracy_score 
import matplotlib.pyplot as plt

from utils.config import print_dict
# Out:
# 2023-09-25 20:53:33.703176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/jcampos/miniforge3/lib/:/home/jcampos/miniforge3/lib/
# 2023-09-25 20:53:33.703203: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
X_train_val = np.load('../data/new-raw-data-all/X_train.npy')
X_test = np.ascontiguousarray(np.load('../data/new-raw-data-all/X_test.npy'))
y_train_val = np.load('../data/new-raw-data-all/y_train.npy')
y_test = np.load('../data/new-raw-data-all/y_test.npy', allow_pickle=True)

# shift = 3
# X_train_val = np.right_shift(X_train_val.astype(np.int32), shift)
# X_test = np.right_shift(X_test.astype(np.int32), shift)

print(X_train_val.max())
# Out:
# 6918.0

# %%
co = {} 
_add_supported_quantized_objects(co)
model = load_model('/data/jcampos/ml-quantum-readout/training/src_keras/qkeras_v2_filter_pnq.h5', custom_objects=co, compile=False)

y_keras = model.predict(X_test)
print(f'Modelv2 (match filter) model acc: {accuracy_score(y_test, np.argmax(y_keras, axis=1))}')
print(model.summary())
# Out:
# 2023-09-25 20:53:37.946301: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/jcampos/miniforge3/lib/:/home/jcampos/miniforge3/lib/
# 2023-09-25 20:53:37.946339: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-09-25 20:53:37.946375: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (correlator3.fnal.gov): /proc/driver/nvidia/version does not exist
# 2023-09-25 20:53:37.946935: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3157/3157 [==============================] - 3s 1ms/step
# Modelv2 (match filter) model acc: 0.9534950495049505
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (QDense)                (None, 2)                 3082
#
#  batch_normalization (BatchN  (None, 2)                8
#  ormalization)
#
# =================================================================
# Total params: 3,090
# Trainable params: 3,086
# Non-trainable params: 4
# _________________________________________________________________
# None

# %%
HLSConfig = {}
HLSConfig['Model'] = {}
HLSConfig['Model']['Precision'] = 'ap_fixed<16,6>'
HLSConfig['Model']['ReuseFactor'] = 1

HLSConfig['LayerName'] = {}
for layer in ['fc1_input', 'fc1', 'fc1_linear', 'batch_normalization']:
    HLSConfig['LayerName'][layer] = {}
    HLSConfig['LayerName'][layer]['Precision'] = {}
    HLSConfig['LayerName'][layer]['Trace'] = True

# Input
HLSConfig['LayerName']['fc1_input']['Precision'] = 'ap_fixed<14,14>'
# Fc
HLSConfig['LayerName']['fc1']['Precision']['result'] = 'ap_fixed<17,17>'
HLSConfig['LayerName']['fc1']['accum_t'] = 'ap_fixed<17,17>'
# Fc Linear
HLSConfig['LayerName']['fc1_linear']['Precision']['result'] = 'ap_fixed<17,17>'
# Batchnormalization
HLSConfig['LayerName']['batch_normalization']['Precision']['scale'] = 'ap_fixed<18,4>'
HLSConfig['LayerName']['batch_normalization']['Precision']['bias'] = 'ap_fixed<18,4>'
HLSConfig['LayerName']['batch_normalization']['Precision']['result'] = 'ap_fixed<18,4>'

print_dict(HLSConfig)
# Out:
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
# LayerName
#   fc1_input
#     Precision:       ap_fixed<14,14>
#     Trace:           True
#   fc1
#     Precision
#       result:        ap_fixed<17,17>
#     Trace:           True
#     accum_t:         ap_fixed<17,17>
#   fc1_linear
#     Precision
#       result:        ap_fixed<17,17>
#     Trace:           True
#   batch_normalization
#     Precision
#       scale:         ap_fixed<18,4>
#       bias:          ap_fixed<18,4>
#       result:        ap_fixed<18,4>
#     Trace:           True

# %%
OutputDir = 'hls4ml_qkeras_v2_match_prj/'
XilinxPart = 'xczu49dr-ffvf1760-2-e'
IOType = 'io_parallel'
ClockPeriod = 3.225
HLSFig = OutputDir+'model.png'

hls_model = hls4ml.converters.convert_from_keras_model(
    model=model,
    hls_config=HLSConfig,
    output_dir=OutputDir,
    part=XilinxPart,
    io_type=IOType,
    clock_period=ClockPeriod,
)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 1540]], output shape: [None, 1540]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 1540]], output shape: [None, 2]
# Layer name: batch_normalization, layer type: BatchNormalization, input shapes: [[None, 2]], output shape: [None, 2]
# Creating HLS model
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "fc1" (Dense)

# %%
print(f"Creating hls4ml project directory {OutputDir}")
hls_model.compile()

# visualize model
hls4ml.utils.plot_model(
    hls_model, show_shapes=True, show_precision=True, to_file=HLSFig
)
# Out:
# Creating hls4ml project directory hls4ml_qkeras_v2_match_prj/
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
# Trace output 
y_hls = hls_model.predict(np.ascontiguousarray(X_test.astype(np.float32))) 
_, hls_trace = hls_model.trace(np.ascontiguousarray(X_test.astype(np.float32))) 

keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, X_test.astype(np.float32))
# Out:
# Recompiling myproject with tracing
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
np.save('v2_hls.npy')

# %%
print(f'Keras Acc: {accuracy_score(y_test, np.argmax(y_keras, axis=1))*100}%')
print(f'HLS Acc: {accuracy_score(y_test, np.argmax(y_hls, axis=1))*100}%')
print(f'CKA: {accuracy_score(np.argmax(y_keras, axis=1), np.argmax(y_hls, axis=1))*100}%')
# Out:
# Keras Acc: 95.34950495049505%
# HLS Acc: 95.409900990099%
# CKA: 99.83267326732673%

# %%
print(f'HLS Keys: {hls_trace.keys()}')
print(f'Keras Keys: {keras_trace.keys()}')
# Out:
# HLS Keys: dict_keys(['fc1', 'batch_normalization'])
# Keras Keys: dict_keys(['fc1', 'fc1_function', 'batch_normalization'])

# %%
layers = ['fc1', 'batch_normalization']

for idx, layer in enumerate(layers):
    keras_layer, hls_layer = keras_trace[layer], hls_trace[layer]
    try:
        diff = np.average(np.abs(keras_layer - hls_layer ))
        print(f'{layer}', '\t\t', diff)
        
        plt.figure(figsize=(7, 5))

        plt.scatter(hls_layer.flatten(), keras_layer.flatten())
        min_x = min(keras_layer.min(), hls_layer.min())
        max_x = min(keras_layer.max(), hls_layer.max())

        onnx_min, onnx_max = keras_layer.flatten().min(), keras_layer.flatten().max()
        hls_min, hls_max = hls_layer.flatten().min(), hls_layer.flatten().max()
        
        print(f'hls/keras min: {hls_min}/{onnx_min}')
        print(f'hls/keras max: {hls_max}/{onnx_max}')
        
        plt.plot([min_x, max_x], [min_x, max_x], c='red')
        plt.axhline(min_x, c='red')
        plt.axhline(max_x, c='red')

        plt.title(f'(hls) {layer} -- (keras) {layer}')
        plt.xlabel(f'hls4ml - [{hls_min:.3f},{hls_max:.3f}]')
        plt.ylabel(f'keras - [{onnx_min:.3f},{onnx_max:.3f}]')
        plt.yscale('linear')
    except Exception as e:
        print(e)
# Out:
# fc1 		 70.426605
# hls/keras min: -45724.0/-45654.03125
# hls/keras max: 46425.0/46495.03125
# batch_normalization 		 0.050710663
# hls/keras min: -6.68927001953125/-6.814767837524414
# hls/keras max: 7.567138671875/7.677910804748535

# %%
hls_model.build(csim=False)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1.1 (64-bit)
#   **** SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
#   **** IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/local/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: Applying HLS Y2K22 patch v1.2 for IP revision
# INFO: [HLS 200-10] Running '/opt/local/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'jcampos' on host 'correlator3.fnal.gov' (Linux_x86_64 version 3.10.0-1160.99.1.el7.x86_64) on Mon Sep 25 01:41:01 CDT 2023
# INFO: [HLS 200-10] On os "Scientific Linux release 7.9 (Nitrogen)"
# INFO: [HLS 200-10] In directory '/data/jcampos/ml-quantum-readout/notebooks/hls4ml_qkeras_v2_match_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/data/jcampos/ml-quantum-readout/notebooks/hls4ml_qkeras_v2_match_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/data/jcampos/ml-quantum-readout/notebooks/hls4ml_qkeras_v2_match_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 60.
# INFO: [HLS 200-10] Setting target device to 'xczu49dr-ffvf1760-2-e'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 3.225ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:16 ; elapsed = 00:00:17 . Memory (MB): peak = 1756.316 ; gain = 1233.910 ; free physical = 39428 ; free virtual = 223461
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:16 ; elapsed = 00:00:17 . Memory (MB): peak = 1756.316 ; gain = 1233.910 ; free physical = 39428 ; free virtual = 223461
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'myproject' (firmware/myproject.cpp:55).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:74).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:79).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:19 ; elapsed = 00:00:20 . Memory (MB): peak = 1756.316 ; gain = 1233.910 ; free physical = 39327 ; free virtual = 223376
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::mantissa' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:15) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::expv' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:18) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::__signbit' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:59) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' into 'generic_cast_IEEE754<int, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:117) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, double>' into '__hls_fptosi_double_i32' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/src/lib_floatconversion.cpp:55) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:73) automatically.
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:19 ; elapsed = 00:00:20 . Memory (MB): peak = 1756.316 ; gain = 1233.910 ; free physical = 39294 ; free virtual = 223346
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:62:55).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:39:55).
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_batchnorm.h:77) in function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:59) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 1540.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:61) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:68) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:73) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 1540.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:74) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:81) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [XFORM 203-131] Reshaping array 'fc1_input.V' (firmware/myproject.cpp:25) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer4_out.V' (firmware/myproject.cpp:26) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer2_out.V' (firmware/myproject.cpp:53) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b2.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:39) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:40) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 's4.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b4.V'  in dimension 1 completely.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::mantissa' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:15) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::expv' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:18) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::__signbit' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:59) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' into 'generic_cast_IEEE754<int, double>' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:117) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, double>' into '__hls_fptosi_double_i32' (/wrk/2020.sub/2020.1.1/continuous/2020_08_05_2960000/src/products/hls/hls_lib/hlsmath/src/lib_floatconversion.cpp:55) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:73) automatically.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>'(firmware/nnet_utils/nnet_batchnorm.h:67:1) to 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0' at call site (firmware/myproject.cpp:60) by setting 'scale[0].V' to 's4.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0'(firmware/nnet_utils/nnet_batchnorm.h:67:1) to 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0' at call site (firmware/myproject.cpp:60) by setting 'scale[1].V' to 's4.V.1'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0'(firmware/nnet_utils/nnet_batchnorm.h:67:1) to 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0' at call site (firmware/myproject.cpp:60) by setting 'bias[0].V' to 'b4.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0'(firmware/nnet_utils/nnet_batchnorm.h:67:1) to 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0.0' at call site (firmware/myproject.cpp:60) by setting 'bias[1].V' to 'b4.V.1'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'(firmware/nnet_utils/nnet_dense_latency.h:48:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0' by setting 'weights.V' to 'w2.V'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0'(firmware/nnet_utils/nnet_dense_latency.h:48:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0' by setting 'biases[0].V' to 'b2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0'(firmware/nnet_utils/nnet_dense_latency.h:48:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' by setting 'biases[1].V' to 'b2.V.1'.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' (firmware/nnet_utils/nnet_mult.h:48:9)...306 expression(s) balanced.
# INFO: [HLS 200-111] Finished Pre-synthesis Time (s): cpu = 00:03:33 ; elapsed = 00:03:36 . Memory (MB): peak = 9049.160 ; gain = 8526.754 ; free physical = 35089 ; free virtual = 219147
# WARNING: [XFORM 203-631] Renaming function 'nnet::normalize<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0.0' to 'normalize<ap_fixed,ap_fixed,config4>.0.0.0.0' (firmware/nnet_utils/nnet_batchnorm.h:67:1)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' to 'dense_latency<ap_fixed,ap_fixed,config2>.0.0.0' (firmware/nnet_utils/nnet_mult.h:48:9)
# INFO: [HLS 200-111] Finished Architecture Synthesis Time (s): cpu = 00:03:37 ; elapsed = 00:03:39 . Memory (MB): peak = 9049.160 ; gain = 8526.754 ; free physical = 35088 ; free virtual = 219146
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'myproject' ...
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_fixed,ap_fixed,config2>.0.0.0' to 'dense_latency_ap_fixed_ap_fixed_config2_0_0_0'.
# WARNING: [SYN 201-103] Legalizing function name 'normalize<ap_fixed,ap_fixed,config4>.0.0.0.0' to 'normalize_ap_fixed_ap_fixed_config4_0_0_0_0'.
# WARNING: [SYN 201-223] Checking resource limit in 'normalize<ap_fixed,ap_fixed,config4>.0.0.0.0': cannot find any operation of 'mul'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_latency_ap_fixed_ap_fixed_config2_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'dense_latency<ap_fixed,ap_fixed,config2>.0.0.0'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 3.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 220.26 seconds; current allocated memory: 336.958 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Starting global binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 5.67 seconds; current allocated memory: 346.532 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'normalize_ap_fixed_ap_fixed_config4_0_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'normalize<ap_fixed,ap_fixed,config4>.0.0.0.0'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 1.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 5.53 seconds; current allocated memory: 347.218 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.03 seconds; current allocated memory: 347.299 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'myproject'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 4.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.05 seconds; current allocated memory: 347.361 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.58 seconds; current allocated memory: 347.667 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_ap_fixed_ap_fixed_config2_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_latency_ap_fixed_ap_fixed_config2_0_0_0' is 21560 from HDL expression: (1'b1 == ap_ce)
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_ap_fixed_ap_fixed_config2_0_0_0'.
# INFO: [HLS 200-111]  Elapsed time: 3.19 seconds; current allocated memory: 365.801 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'normalize_ap_fixed_ap_fixed_config4_0_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'normalize_ap_fixed_ap_fixed_config4_0_0_0_0'.
# INFO: [HLS 200-111]  Elapsed time: 8.03 seconds; current allocated memory: 402.387 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/fc1_input_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer4_out_0_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer4_out_1_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject' to 'ap_ctrl_hs'.
# INFO: [RTGEN 206-104] Estimated max fanout for 'myproject' is 21565 from HDL expression: ap_rst
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [HLS 200-111]  Elapsed time: 0.5 seconds; current allocated memory: 402.998 MB.
# INFO: [HLS 200-789] **** Estimated Fmax: 362.09 MHz
# INFO: [HLS 200-111] Finished generating all RTL models Time (s): cpu = 00:04:08 ; elapsed = 00:04:14 . Memory (MB): peak = 9049.160 ; gain = 8526.754 ; free physical = 35044 ; free virtual = 219141
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h4m12s *****
# INFO: [HLS 200-112] Total elapsed time: 254.26 seconds; peak allocated memory: 402.998 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Mon Sep 25 01:45:15 2023...
# Vivado synthesis report not found.
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'EstimatedClockPeriod': '2.762',
#   'BestLatency': '3',
#   'WorstLatency': '3',
#   'IntervalMin': '1',
#   'IntervalMax': '1',
#   'DSP48E': '17',
#   'FF': '45777',
#   'LUT': '13576',
#   'BRAM_18K': '0',
#   'URAM': '0',
#   'AvailableBRAM_18K': '2160',
#   'AvailableDSP48E': '4272',
#   'AvailableFF': '850560',
#   'AvailableLUT': '425280',
#   'AvailableURAM': '80'}}

# %%
gamma, beta, mean, var = model.layers[1].weights

# %%
epsilon = 0.001
scale = gamma / np.sqrt(var + epsilon)
print(scale)
# Out:
# tf.Tensor([9.151131e-06 8.555250e-06], shape=(2,), dtype=float32)

# %%
epsilon = 0.001
bias = -1 * mean / np.sqrt(var + epsilon) * gamma + beta 
bias
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([ 1.8962208, -1.66418  ], dtype=float32)>

# %%
keras_trace['fc1']
# Out:
# array([[-525980.,  597115.],
#        [-471635.,  298742.],
#        [-524014.,  548216.],
#        ...,
#        [-403696.,  268583.],
#        [-524719.,  359208.],
#        [-272128.,  326140.]], dtype=float32)

# %%
hls_trace['fc1']
# Out:
# array([[-525980.,  597115.],
#        [-471635.,  298742.],
#        [-524014.,  548216.],
#        ...,
#        [-403696.,  268583.],
#        [-524719.,  359208.],
#        [-272128.,  326140.]], dtype=float32)

# %%
keras_trace['batch_normalization']
# Out:
# array([[-2.9170914 ,  3.4442883 ],
#        [-2.419773  ,  0.89163256],
#        [-2.8991003 ,  3.0259452 ],
#        ...,
#        [-1.7980541 ,  0.6336148 ],
#        [-2.9055514 ,  1.4089344 ],
#        [-0.59405816,  1.1260293 ]], dtype=float32)

# %%
hls_trace['batch_normalization']
# Out:
# array([[ 1.8961182, -1.6641846],
#        [ 1.8961182, -1.6641846],
#        [ 1.8961182, -1.6641846],
#        ...,
#        [ 1.8961182, -1.6641846],
#        [ 1.8961182, -1.6641846],
#        [ 1.8961182, -1.6641846]], dtype=float32)

# %%
hls_trace['batch_normalization'].shape
# Out:
# (101000, 2)

# %%
plt.figure()
plt.plot(keras_trace['batch_normalization'].reshape(-1)[:30], label='Keras')
plt.plot(hls_trace['batch_normalization'].reshape(-1)[:30], label='HLS')
plt.legend(loc='upper left')

# %%
keras_trace['batch_normalization'].shape
# Out:
# (202000, 2)

# %%
import math 

math.log2(48000)
# Out:
# 15.550746785383243
